# %%
import pandas as pd
import matplotlib.pyplot as plt
baseline = pd.read_csv("C:\\Users\\micha\\OneDrive\\桌面\\CODES\\Machine Learning\\HW1\Result\\Baseline\\Jan20_18-03-59_MICHAELKAO.csv")
plt.plot(baseline['Step'], baseline['train_loss'], label="Train Loss")
plt.plot(baseline['Step'], baseline['valid_loss'], label='Validation Loss', alpha = 0.7)
plt.ylim([0,10])
plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot(x = baseline['step'], y = baseline['train_loss'])
#       2 plt.show()
#
# NameError: name 'plot' is not defined
